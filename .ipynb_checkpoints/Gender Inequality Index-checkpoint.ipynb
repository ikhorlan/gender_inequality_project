# %% [markdown]
# # Gender Inequality Index

# %% [markdown]
# The Gender Inequality Index (GII) provides a comprehensive measure of gender inequality across countries, capturing gender disparities in health, education, and economic opportunities. Developed by the United Nations Development Programme (UNDP), the GII measures gender inequality by analyzing health, empowerment, and labor market participation indicators.
#
# This dataset from Kaggle includes GII scores, as well as component scores for each indicator, for over 190 countries, in 2021.

# %% [markdown]
# # Project goal

# %% [markdown]
# The target variable or variables under this project will be health indicators of maternal mortality and adolescent birth rate and how they depend on the GII or the proportion of women in the parliament.
#
# The question of this EDA is to see if countries can improve their health indicators by increasing the number of women parliamentarians.
#
# The features used in this project are social determinants of inequlity such as health (maternal mortality), education (adolescents birth rate, secondary education by gender) and political (parliametary seats) influence gender inequalities.
#
# Risks or limitations: this dataset does not provide other information such as income or mental health issues. In addition, GII may be important for more developed countries where this index is already high.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
RANDOM_STATE = 42

# %%
import folium

# %%
gen_inequal=pd.read_csv('../final_proposal_data/Gender_Inequality_Index.csv')

# %%
gen_inequal.head()
# Out:
#        Country Human_development    GII  Rank  Maternal_mortality  \
# 0  Switzerland         Very high  0.018   3.0                 5.0
# 1       Norway         Very high  0.016   2.0                 2.0
# 2      Iceland         Very high  0.043   8.0                 4.0
# 3    Hong Kong         Very high    NaN   NaN                 NaN
# 4    Australia         Very high  0.073  19.0                 6.0
#
#    Adolescent_birth_rate  Seats_parliament  F_secondary_educ  \
# 0                    2.2              39.8              96.9
# 1                    2.3              45.0              99.1
# 2                    5.4              47.6              99.8
# 3                    1.6               NaN              77.1
# 4                    8.1              37.9              94.6
#
#    M_secondary_educ  F_Labour_force  M_Labour_force
# 0              97.5            61.7            72.7
# 1              99.3            60.3            72.0
# ...

# %%
gen_inequal.shape
# Out:
# (195, 11)

# %%
gen_inequal.dtypes
# Out:
# Country                   object
# Human_development         object
# GII                      float64
# Rank                     float64
# Maternal_mortality       float64
# Adolescent_birth_rate    float64
# Seats_parliament         float64
# F_secondary_educ         float64
# M_secondary_educ         float64
# F_Labour_force           float64
# M_Labour_force           float64
# dtype: object

# %%
gen_inequal.describe()
# Out:
#               GII        Rank  Maternal_mortality  Adolescent_birth_rate  \
# count  170.000000  170.000000          184.000000             195.000000
# mean     0.344376   85.376471          160.027174              44.597949
# std      0.197105   49.210206          233.028867              38.422479
# min      0.013000    1.000000            2.000000               1.600000
# 25%      0.177500   43.250000           12.750000              10.750000
# 50%      0.363000   85.500000           53.000000              36.200000
# 75%      0.505750  127.750000          188.250000              64.200000
# max      0.820000  170.000000         1150.000000             170.500000
#
#        Seats_parliament  F_secondary_educ  M_secondary_educ  F_Labour_force  \
# count        193.000000        177.000000        177.000000      180.000000
# mean          24.701554         62.706780         67.068362       50.224444
# std           12.404319         29.528487         26.450033       15.905491
# ...

# %%
gen_inequal.sort_values('Seats_parliament', ascending=False)
# Out:
#                             Country Human_development    GII   Rank  \
# 164                          Rwanda               Low  0.388   93.0
# 82                             Cuba              High  0.303   73.0
# 125                       Nicaragua            Medium  0.424  102.0
# 25             United Arab Emirates         Very high  0.049   11.0
# 85                           Mexico              High  0.309   75.0
# ..                              ...               ...    ...    ...
# 141                         Vanuatu            Medium    NaN    NaN
# 156                Papua New Guinea            Medium  0.725  169.0
# 92                            Tonga              High  0.631  160.0
# 3                         Hong Kong         Very high    NaN    NaN
# 105  Palestinian National Authority              High    NaN    NaN
#
#      Maternal_mortality  Adolescent_birth_rate  Seats_parliament  \
# 164               248.0                   32.4              55.7
# ...

# %%
gen_inequal.sort_values('Maternal_mortality', ascending=False)
# Out:
#               Country Human_development    GII   Rank  Maternal_mortality  \
# 190       South Sudan               Low  0.587  150.0              1150.0
# 189              Chad               Low  0.652  165.0              1140.0
# 180      Sierra Leone               Low  0.633  162.0              1120.0
# 163           Nigeria               Low  0.680  168.0               917.0
# 194           Somalia               NaN    NaN    NaN               829.0
# ..                ...               ...    ...    ...                 ...
# 101          Dominica              High    NaN    NaN                 NaN
# 129            Tuvalu            Medium    NaN    NaN                 NaN
# 130  Marshall Islands            Medium    NaN    NaN                 NaN
# 192            Monaco               NaN    NaN    NaN                 NaN
# 193             Nauru               NaN    NaN    NaN                 NaN
#
#      Adolescent_birth_rate  Seats_parliament  F_secondary_educ  \
# ...

# %%
gen_inequal.sort_values('Adolescent_birth_rate', ascending=False)
# Out:
#                       Country Human_development    GII   Rank  \
# 188                     Niger               Low  0.611  153.0
# 184                Mozambique               Low  0.537  136.0
# 187  Central African Republic               Low  0.672  166.0
# 185                      Mali               Low  0.613  155.0
# 144         Equatorial Guinea            Medium    NaN    NaN
# ..                        ...               ...    ...    ...
# 1                      Norway         Very high  0.016    2.0
# 19                South Korea         Very high  0.067   15.0
# 0                 Switzerland         Very high  0.018    3.0
# 5                     Denmark         Very high  0.013    1.0
# 3                   Hong Kong         Very high    NaN    NaN
#
#      Maternal_mortality  Adolescent_birth_rate  Seats_parliament  \
# 188               509.0                  170.5              25.9
# 184               289.0                  165.8              42.4
# ...

# %% [markdown]
# The dataset sorted by seats in the parliament (women parliametarian) has Rwanda, Cuba, Nicaragua, Arab Emirates and Mexico as top countries with the maximum proportion of women parliamentarians. However, maternal mortality in Rwanda and adolescent preganacy rates in Nicaragua, Cuba and Mexico are much higher than the mean values.

# %%
gen_inequal.corr()
# Out:
#                             GII      Rank  Maternal_mortality  \
# GII                    1.000000  0.996755            0.713515
# Rank                   0.996755  1.000000            0.733578
# Maternal_mortality     0.713515  0.733578            1.000000
# Adolescent_birth_rate  0.806791  0.820780            0.745658
# Seats_parliament      -0.424116 -0.419945           -0.147847
# F_secondary_educ      -0.809278 -0.811686           -0.697939
# M_secondary_educ      -0.782130 -0.781625           -0.642114
# F_Labour_force        -0.070970 -0.050753            0.181069
# M_Labour_force         0.158270  0.160078            0.043856
#
#                        Adolescent_birth_rate  Seats_parliament  \
# GII                                 0.806791         -0.424116
# Rank                                0.820780         -0.419945
# Maternal_mortality                  0.745658         -0.147847
# Adolescent_birth_rate               1.000000         -0.118194
# ...

# %% [markdown]
# Maternal mortality is highly correlated with the gender inequality index. In contries with higher GII, maternal mortality is higher. The same for adolescent birth rate. Both indicators are intercorrelated and both indicators are negatively correlated with female and male secondary educaton. the correlation of maternal mortality and adolescent pregnancy with the seats in the parliament is negative but very weak.

# %%
gen_inequal_mmr=gen_inequal.groupby(
    'Human_development').agg({
    'GII':'mean', 
    'Maternal_mortality':'mean', 
    'Seats_parliament':'mean', 
    'Adolescent_birth_rate':'mean'}).sort_values("GII", ascending=False)

# %%
gen_inequal_mmr
# Out:
#                         GII  Maternal_mortality  Seats_parliament  \
# Human_development
# Low                0.593867          521.468750         22.700000
# Medium             0.479472          197.642857         20.975000
# High               0.341690           58.086957         24.247917
# Very high          0.147032           13.983871         28.741538
#
#                    Adolescent_birth_rate
# Human_development
# Low                            95.143750
# Medium                         64.459091
# High                           35.997959
# Very high                      12.907576

# %% [markdown]
# Groupby method shows high GII, maternal mortality and adlescent preganacy rates in low human development countries.

# %%
gen_inequal.plot.scatter(x='Maternal_mortality', y='Seats_parliament');

# %%
gen_inequal.plot.scatter(x='Adolescent_birth_rate', y='Seats_parliament')
# Out:
# <AxesSubplot:xlabel='Adolescent_birth_rate', ylabel='Seats_parliament'>

# %% [markdown]
# There is no correaltion between maternal mortality with seats in parliament and adolescnet preganacy rates with seats in parliament.

# %%
gen_inequal.plot.scatter(x='Seats_parliament', y='GII', alpha=0.4)
# Out:
# <AxesSubplot:xlabel='Seats_parliament', ylabel='GII'>

# %%
ax=gen_inequal_mmr.plot.barh()
ax.set_title("GII by Human Development Index", fontsize=18)
# Out:
# Text(0.5, 1.0, 'GII by Human Development Index')

# %%
gen_inequal.GII.hist(bins='auto')
# Out:
# <AxesSubplot:>

# %%
gen_inequal.Maternal_mortality.hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
gen_inequal.Adolescent_birth_rate.hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
gen_inequal.Seats_parliament.hist(bins='auto')
# Out:
# <AxesSubplot:>

# %%
# Цены за кв. метр по п. Шушары и п. Мурино
x = gen_inequal.F_secondary_educ
y = gen_inequal.M_secondary_educ

bins = np.linspace(0, 100)

plt.hist(x, bins=45, alpha=1.0, label='Female Secondary Education')
plt.hist(y, bins=50, alpha=1.0, label='Male Secondary Education')
plt.legend(loc='upper left')
plt.show()

# %%
x = gen_inequal.F_Labour_force
y = gen_inequal.M_Labour_force

bins = np.linspace(0, 100)

plt.hist(x, bins=40, alpha=1.0, label='Female Labour Force')
plt.hist(y, bins=50, alpha=1.0, label='Male Labour Force')
plt.legend(loc='upper left')
plt.show()

# %%
gen_inequal['Human_development'] = pd.Categorical(gen_inequal['Human_development'], categories=['Low', 'Medium', 'High', 'Very high'], ordered=True)

# %%
gii_seats=gen_inequal.groupby(
    'Human_development').agg(
    {'GII':'mean', 
     'Seats_parliament':'mean'}).sort_values('Human_development'
)

# %%
ax=gen_inequal.boxplot(column='GII', by='Human_development', figsize=(8, 6), rot=0, vert=False)

# %%
ax_mm=gen_inequal.boxplot(column='Maternal_mortality', by='Human_development', figsize=(8, 6), rot=0, vert=False)

# %%
ax_ab=gen_inequal.boxplot(column='Adolescent_birth_rate', by='Human_development', figsize=(8, 6), rot=0, vert=False)

# %% [markdown]
# The boxplot show several outlier countries in almost each human development category.

# %%
gen_low=gen_inequal[gen_inequal['Human_development']=='Low']
gen_low
# Out:
#                       Country Human_development    GII   Rank  \
# 159                  Tanzania               Low  0.560  146.0
# 160                  Pakistan               Low  0.534  135.0
# 161                      Togo               Low  0.580  149.0
# 162                     Haiti               Low  0.635  163.0
# 163                   Nigeria               Low  0.680  168.0
# 164                    Rwanda               Low  0.388   93.0
# 165                     Benin               Low  0.602  152.0
# 166                    Uganda               Low  0.530  131.0
# 167                   Lesotho               Low  0.557  144.0
# 168                    Malawi               Low  0.554  142.0
# 169                   Senegal               Low  0.530  131.0
# 170                  Djibouti               Low    NaN    NaN
# 171                     Sudan               Low  0.553  141.0
# 172                Madagascar               Low  0.556  143.0
# ...

# %% [markdown]
# Sierra  Leone, Chad and South Sudan are outliers in the box plots for maternal mortality.

# %%
gen_med=gen_inequal[gen_inequal['Human_development']=='Medium']
gen_med
# Out:
#                             Country Human_development    GII   Rank  \
# 115                     Philippines            Medium  0.419  101.0
# 116                        Botswana            Medium  0.468  117.0
# 117                         Bolivia            Medium  0.418   99.0
# 118                      Kyrgyzstan            Medium  0.370   87.0
# 119                       Venezuela            Medium  0.492  123.0
# 120                            Iraq            Medium  0.558  145.0
# 121                      Tajikistan            Medium  0.285   68.0
# 122                          Belize            Medium  0.364   86.0
# 123                         Morocco            Medium  0.425  104.0
# 124                     El Salvador            Medium  0.376   88.0
# 125                       Nicaragua            Medium  0.424  102.0
# 126                          Bhutan            Medium  0.415   98.0
# 127                      Cape Verde            Medium  0.349   84.0
# ...

# %% [markdown]
# Equatorial Guinea and Angola and Zambia are ourliers for adolescent birth rate and Eswatini, Zimbabwe, Cameroon, Mauritania and Cote d'Ivoire are outliers for maternal mortality rate.

# %%
gen_hi=gen_inequal[gen_inequal['Human_development']=='High']
gen_hi
# Out:
#                               Country Human_development    GII   Rank  \
# 66                            Albania              High  0.144   39.0
# 67                           Bulgaria              High  0.210   52.0
# 68                            Grenada              High    NaN    NaN
# 69                           Barbados              High  0.268   64.0
# 70                Antigua and Barbuda              High    NaN    NaN
# 71                         Seychelles              High    NaN    NaN
# 72                          Sri Lanka              High  0.383   92.0
# 73             Bosnia and Herzegovina              High  0.136   38.0
# 74              Saint Kitts and Nevis              High    NaN    NaN
# 75                               Iran              High  0.459  115.0
# 76                            Ukraine              High  0.200   49.0
# 77        Republic of North Macedonia              High  0.134   37.0
# ...

# %% [markdown]
# Guyana, Gabon and Indonesia are the countries outliers in the above box plots for maternal mortality and adolescent birth rates.

# %%
gen_vhi=gen_inequal[gen_inequal['Human_development']=='Very high']
gen_vhi.sort_values('Adolescent_birth_rate', ascending=False)
# Out:
#                 Country Human_development    GII  Rank  Maternal_mortality  \
# 60               Panama         Very high  0.392  96.0                52.0
# 46            Argentina         Very high  0.287  69.0                39.0
# 56  Trinidad and Tobago         Very high  0.344  81.0                67.0
# 57           Costa Rica         Very high  0.256  60.0                27.0
# 52              Romania         Very high  0.282  67.0                19.0
# ..                  ...               ...    ...   ...                 ...
# 1                Norway         Very high  0.016   2.0                 2.0
# 19          South Korea         Very high  0.067  15.0                11.0
# 0           Switzerland         Very high  0.018   3.0                 5.0
# 5               Denmark         Very high  0.013   1.0                 4.0
# 3             Hong Kong         Very high    NaN   NaN                 NaN
#
#     Adolescent_birth_rate  Seats_parliament  F_secondary_educ  \
# ...

# %% [markdown]
# Argentina, Trinidad Tobago and Costa Rica have high maternal mortality and adolescent birth rates with high parlimentary seats.

# %% [markdown]
# <h4>Mapping<h>

# %%
gen_inequal["Country"].replace({'United States': 'United States of America'}, inplace=True)
gen_inequal["Country"].replace({'Congo (DRC)': 'Democratic Republic of the Congo'}, inplace=True)
gen_inequal["Country"].replace({'Tanzania': 'United Republic of Tanzania'}, inplace=True)
gen_inequal["Country"].replace({'Congo': 'Republic of the Congo'}, inplace=True)
gen_inequal["Country"].replace({'Serbia': 'Republic of Serbia'}, inplace=True)
gen_inequal["Country"].replace({'Guinea-Bissau': 'Guinea Bissau'}, inplace=True)
gen_inequal["Country"].replace({'Serbia': 'Republic of Serbia'}, inplace=True)
gen_inequal["Country"].replace({'Republic of North Macedonia': 'Macedonia'}, inplace=True)

# %%
m=folium.Map(location=[0,0], zoom_start=2)

# %%
folium.Choropleth(
    geo_data='world-countries.json',
    name='choropleth',
    data=gen_inequal,
    columns=['Country', 'GII'],
    key_on='feature.properties.name',
    fill_color='YlGn',
    line_opacity=0.2,
    legend_name='GII'
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m_mmr=folium.Map(location=[0,0], zoom_start=2)

# %%
folium.Choropleth(
    geo_data='world-countries.json',
    name='choropleth',
    data=gen_inequal,
    columns=['Country', 'Maternal_mortality'],
    key_on='feature.properties.name',
    fill_color='YlGn',
    line_opacity=0.2,
    legend_name='GII'
).add_to(m_mmr)

m_mmr
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m_abr=folium.Map(location=[0,0], zoom_start=2)

# %%
folium.Choropleth(
    geo_data='world-countries.json',
    name='choropleth',
    data=gen_inequal,
    columns=['Country', 'Adolescent_birth_rate'],
    key_on='feature.properties.name',
    fill_color='YlGn',
    line_opacity=0.2,
    legend_name='GII'
).add_to(m_abr)

m_abr
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h4>Decision Trees<h4>

# %%
gen_ii=gen_inequal.copy()

# %%
gen_ii=gen_ii.dropna()
gen_ii = (
    gen_ii
    .select_dtypes(include='number')
)

# %%
from sklearn.tree  import DecisionTreeRegressor 
from sklearn.model_selection import train_test_split
from sklearn import tree
from model_inspector import get_inspector

# %%
columns = ['Maternal_mortality', 'Adolescent_birth_rate', 'Seats_parliament']

feature_importances = {}

for column in columns:
        
    X = gen_ii.drop([column, 'GII', 'Rank'], axis=1)
    y = gen_ii[column]
    
    regressor = DecisionTreeRegressor(random_state=RANDOM_STATE)
    regressor.fit(X, y)
    
    inspector = get_inspector(regressor, X, y)
    ax = inspector.show_model(max_depth=3)
    
    importances = regressor.feature_importances_
    
    feature_importances[column] = dict(zip(X.columns, importances))

for column, importances in feature_importances.items():
    print("Feature Importances for Target Column:", column)
    sorted_importances = sorted(importances.items(), key=lambda x: x[1], reverse=True)
    for feature, importance in sorted_importances:
        print(feature, ":", importance)
    print()
# Out:
# Feature Importances for Target Column: Maternal_mortality
# Adolescent_birth_rate : 0.6096138424129441
# F_secondary_educ : 0.17893725094709814
# F_Labour_force : 0.08041016584641152
# M_Labour_force : 0.07354440161393903
# Seats_parliament : 0.03532360422534283
# M_secondary_educ : 0.022170734954264356
#
# Feature Importances for Target Column: Adolescent_birth_rate
# Maternal_mortality : 0.7607830289670788
# M_Labour_force : 0.07428404916761298
# F_Labour_force : 0.07150511519345101
# Seats_parliament : 0.04943296957298214
# M_secondary_educ : 0.026772185157020782
# F_secondary_educ : 0.017222651941854124
#
# Feature Importances for Target Column: Seats_parliament
# Maternal_mortality : 0.22504456210241244
# F_secondary_educ : 0.22223095578597118
# F_Labour_force : 0.20363996422267436
# Adolescent_birth_rate : 0.17068233045228404
# M_Labour_force : 0.11805078754434899
# M_secondary_educ : 0.060351399892309164
